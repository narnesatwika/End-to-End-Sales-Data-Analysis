# %%
import pandas
import numpy
import matplotlib
import seaborn
import sklearn

print("All Required Libraries Are Installed Successfully!")
# Out:
# All Required Libraries Are Installed Successfully!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy
import statsmodels
import plotly
import openpyxl

print("Everything is Installed Successfully!")
# Out:
# Everything is Installed Successfully!

# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split


import warnings
warnings.filterwarnings('ignore')


plt.style.use('ggplot')


pd.set_option('display.max_columns', None)


pd.set_option('display.max_rows', 100)

print("=" * 60)
print("🎉 All Required Libraries Imported Successfully!")
print("=" * 60)
# Out:
# ...
# 🎉 All Required Libraries Imported Successfully!
# ...

# %%
import pandas as pd

print("Pandas library imported successfully!")
# Out:
# Pandas library imported successfully!

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Narne.sathwika\Documents

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'My Music', 'My Pictures', 'My Videos', 'sales_data_sample.csv', 'sales_data_sample.ipynb']

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Narne.sathwika\Documents
# ['.ipynb_checkpoints', 'My Music', 'My Pictures', 'My Videos', 'sales_data_sample.csv', 'sales_data_sample.ipynb']

# %%
import pandas as pd

sales_data = pd.read_csv("sales_data_sample.csv", encoding="latin1")

print("Dataset Loaded Successfully!")

sales_data.head()
# Out:
# Dataset Loaded Successfully!
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95
# 1    5/7/2003 0:00  Shipped       2         5     2003  Motorcycles    95
# 2    7/1/2003 0:00  Shipped       3         7     2003  Motorcycles    95
# 3   8/25/2003 0:00  Shipped       3         8     2003  Motorcycles    95
# 4  10/10/2003 0:00  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# ...

# %%
sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95
# 1    5/7/2003 0:00  Shipped       2         5     2003  Motorcycles    95
# 2    7/1/2003 0:00  Shipped       3         7     2003  Motorcycles    95
# 3   8/25/2003 0:00  Shipped       3         8     2003  Motorcycles    95
# 4  10/10/2003 0:00  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# ...

# %%
sales_data.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID PRODUCTLINE  MSRP  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004       Ships    54
# 2819  1/31/2005 0:00   Shipped       1         1     2005       Ships    54
# 2820   3/1/2005 0:00  Resolved       1         3     2005       Ships    54
# 2821  3/28/2005 0:00   Shipped       1         3     2005       Ships    54
# 2822   5/6/2005 0:00   On Hold       2         5     2005       Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME           PHONE  \
# ...

# %%
#Check Number of Rows and Columns
sales_data.shape
# Out:
# (2823, 25)

# %%
# STEP 6: Display All Column Names

sales_data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
# STEP 7: Dataset Information
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
# STEP 8: Statistical Summary
sales_data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
# STEP 9: Check Missing Values
sales_data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# STEP 10: Check Duplicate Records
sales_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# STEP 11: Display Data Types
sales_data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# STEP 12 : Create Backup Copy
sales_data_copy = sales_data.copy()

print("Backup copy created successfully!")
# Out:
# Backup copy created successfully!

# %%
# STEP 13 : Missing Values
missing_values = sales_data.isnull().sum()
missing_values
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# STEP 14 : Columns with Missing Values
missing_values = sales_data.isnull().sum()

missing_values[missing_values > 0]
# Out:
# ADDRESSLINE2    2521
# STATE           1486
# POSTALCODE        76
# TERRITORY       1074
# dtype: int64

# %%
# STEP 15 : Percentage of Missing Values
missing_percentage = (sales_data.isnull().sum() / len(sales_data)) * 100

missing_percentage[missing_percentage > 0]
# Out:
# ADDRESSLINE2    89.302161
# STATE           52.639036
# POSTALCODE       2.692171
# TERRITORY       38.044633
# dtype: float64

# %%
#remove duplicate values
sales_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# STEP 16 : Remove Duplicate Rows
sales_data = sales_data.drop_duplicates()

print("Duplicate rows removed successfully!")
# Out:
# Duplicate rows removed successfully!

# %%
sales_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# STEP 17 : Data Types

sales_data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# STEP 18 : Convert Date Column

sales_data["ORDERDATE"] = pd.to_datetime(sales_data["ORDERDATE"])

print("ORDERDATE converted successfully!")
# Out:
# ORDERDATE converted successfully!

# %%
sales_data.shape
# Out:
# (2823, 25)

# %%
missing_percentage[missing_percentage > 0]
# Out:
# ADDRESSLINE2    89.302161
# STATE           52.639036
# POSTALCODE       2.692171
# TERRITORY       38.044633
# dtype: float64

# %%
sales_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales_data.dtypes
# Out:
# ORDERNUMBER                  int64
# QUANTITYORDERED              int64
# PRICEEACH                  float64
# ORDERLINENUMBER              int64
# SALES                      float64
# ORDERDATE           datetime64[ns]
# STATUS                      object
# QTR_ID                       int64
# MONTH_ID                     int64
# YEAR_ID                      int64
# PRODUCTLINE                 object
# MSRP                         int64
# PRODUCTCODE                 object
# CUSTOMERNAME                object
# PHONE                       object
# ADDRESSLINE1                object
# ADDRESSLINE2                object
# CITY                        object
# STATE                       object
# POSTALCODE                  object
# COUNTRY                     object
# TERRITORY                   object
# CONTACTLASTNAME             object
# CONTACTFIRSTNAME            object
# DEALSIZE                    object
# dtype: object

# %%
#exploratory data analysis
#Total Sales
total_sales = sales_data["SALES"].sum()

print("Total Sales =", total_sales)
# Out:
# Total Sales = 10032628.85

# %%
#Average Sales

average_sales = sales_data["SALES"].mean()

print("Average Sales =", average_sales)
# Out:
# Average Sales = 3553.889071909316

# %%
#Highest Sale

highest_sale = sales_data["SALES"].max()

print("Highest Sale =", highest_sale)
# Out:
# Highest Sale = 14082.8

# %%
# EDA Step 4 : Lowest Sale

lowest_sale = sales_data["SALES"].min()

print("Lowest Sale =", lowest_sale)
# Out:
# Lowest Sale = 482.13

# %%
#Sales Distribution


import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.hist(sales_data["SALES"], bins=30)

plt.title("Distribution of Sales")

plt.xlabel("Sales")

plt.ylabel("Frequency")

plt.show()

# %%
#Top Product Lines


top_products = sales_data.groupby("PRODUCTLINE")["SALES"].sum().sort_values(ascending=False)

top_products
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Vintage Cars        1903150.84
# Motorcycles         1166388.34
# Trucks and Buses    1127789.84
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Name: SALES, dtype: float64

# %%
#Product Line Chart

plt.figure(figsize=(10,6))

top_products.plot(kind="bar")

plt.title("Total Sales by Product Line")

plt.xlabel("Product Line")

plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
#Sales by Country

country_sales = sales_data.groupby("COUNTRY")["SALES"].sum().sort_values(ascending=False)

country_sales
# Out:
# COUNTRY
# USA            3627982.83
# Spain          1215686.92
# France         1110916.52
# Australia       630623.10
# UK              478880.46
# Italy           374674.31
# Finland         329581.91
# Norway          307463.70
# Singapore       288488.41
# Denmark         245637.15
# Canada          224078.56
# Germany         220472.09
# Sweden          210014.21
# Austria         202062.53
# Japan           188167.81
# Switzerland     117713.56
# Belgium         108412.62
# Philippines      94015.73
# Ireland          57756.43
# Name: SALES, dtype: float64

# %%
#country sales chart
plt.figure(figsize=(12,6))

country_sales.plot(kind="bar")

plt.title("Sales by Country")

plt.xlabel("Country")

plt.ylabel("Sales")

plt.xticks(rotation=90)

plt.show()

# %%
#monthly sales
monthly_sales = sales_data.groupby("MONTH_ID")["SALES"].sum()

monthly_sales
# Out:
# MONTH_ID
# 1      785874.44
# 2      810441.90
# 3      754501.39
# 4      669390.96
# 5      923972.56
# 6      454756.78
# 7      514875.97
# 8      659310.57
# 9      584724.27
# 10    1121215.22
# 11    2118885.67
# 12     634679.12
# Name: SALES, dtype: float64

# %%
#monthly sales chart
plt.figure(figsize=(10,5))

monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.grid(True)

plt.show()

# %%
import plotly.express as px

# %%
#Interactive sales by product line
product_sales = sales_data.groupby("PRODUCTLINE")["SALES"].sum().reset_index()

fig = px.bar(
    product_sales,
    x="PRODUCTLINE",
    y="SALES",
    color="SALES",
    title="Total Sales by Product Line",
    text_auto=".2s"
)

fig.show()

# %%
#Monthly sales trend
monthly_sales = sales_data.groupby("MONTH_ID")["SALES"].sum().reset_index()

fig = px.line(
    monthly_sales,
    x="MONTH_ID",
    y="SALES",
    markers=True,
    title="Monthly Sales Trend"
)

fig.show()

# %%
#Sales by country
country_sales = sales_data.groupby("COUNTRY")["SALES"].sum().reset_index()

fig = px.bar(
    country_sales,
    x="COUNTRY",
    y="SALES",
    color="SALES",
    title="Country-wise Sales"
)

fig.show()

# %%
#Product share
fig = px.pie(
    product_sales,
    values="SALES",
    names="PRODUCTLINE",
    title="Sales Contribution by Product Line"
)

fig.show()

# %%
#Order status
status = sales_data["STATUS"].value_counts().reset_index()

status.columns = ["STATUS", "COUNT"]

fig = px.bar(
    status,
    x="STATUS",
    y="COUNT",
    color="COUNT",
    title="Order Status Distribution"
)

fig.show()

# %%
#Top 10 customers names
top_customers = (
    sales_data.groupby("CUSTOMERNAME")["SALES"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig = px.bar(
    top_customers,
    x="CUSTOMERNAME",
    y="SALES",
    color="SALES",
    title="Top 10 Customers"
)

fig.update_layout(xaxis_tickangle=-45)

fig.show()

# %%
#Year wise sales
year_sales = sales_data.groupby("YEAR_ID")["SALES"].sum().reset_index()

fig = px.bar(
    year_sales,
    x="YEAR_ID",
    y="SALES",
    color="SALES",
    title="Year-wise Sales"
)

fig.show()

# %%
#Sales distribution
fig = px.histogram(
    sales_data,
    x="SALES",
    nbins=40,
    title="Distribution of Sales"
)

fig.show()

# %%
#Quantity Vs sales
fig = px.scatter(
    sales_data,
    x="QUANTITYORDERED",
    y="SALES",
    color="PRODUCTLINE",
    title="Quantity Ordered vs Sales"
)

fig.show()

# %%
#Deal size analysis
deal_sales = sales_data.groupby("DEALSIZE")["SALES"].sum().reset_index()

fig = px.bar(
    deal_sales,
    x="DEALSIZE",
    y="SALES",
    color="DEALSIZE",
    title="Sales by Deal Size"
)

fig.show()

# %%
#Corelation heat map
import matplotlib.pyplot as plt

numeric_data = sales_data.select_dtypes(include=["int64", "float64"])

correlation = numeric_data.corr()

plt.figure(figsize=(10,8))

plt.imshow(correlation)

plt.colorbar()

plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)

plt.yticks(range(len(correlation.columns)), correlation.columns)

plt.title("Correlation Heatmap")

plt.show()

# %%
#Sales distribution by product line
import plotly.express as px

product_sales = sales_data.groupby("PRODUCTLINE")["SALES"].sum().reset_index()

fig = px.pie(
    product_sales,
    values="SALES",
    names="PRODUCTLINE",
    title="Sales Contribution by Product Line",
    hole=0.4
)

fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()

# %%
#sales distribution by deal size
deal_sales = sales_data.groupby("DEALSIZE")["SALES"].sum().reset_index()

fig = px.pie(
    deal_sales,
    values="SALES",
    names="DEALSIZE",
    title="Sales Contribution by Deal Size",
    hole=0.4
)

fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()

# %%
#Year wise sales trend
year_sales = sales_data.groupby("YEAR_ID")["SALES"].sum().reset_index()

fig = px.line(
    year_sales,
    x="YEAR_ID",
    y="SALES",
    markers=True,
    title="Year-wise Sales Trend"
)

fig.update_layout(
    xaxis_title="Year",
    yaxis_title="Total Sales"
)

fig.show()

# %%
#extracting the day
sales_data["DAY"] = sales_data["ORDERDATE"].dt.day

sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
#Extracting month name
sales_data["MONTH_NAME"] = sales_data["ORDERDATE"].dt.month_name()

sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
#Extracting day name
sales_data["DAY_NAME"] = sales_data["ORDERDATE"].dt.day_name()

sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
#Extracting quarter
sales_data["QUARTER"] = sales_data["ORDERDATE"].dt.quarter

sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
#extracting weeday or weekend
sales_data["IS_WEEKEND"] = sales_data["DAY_NAME"].isin(["Saturday","Sunday"])

sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# ...

# %%
#Top 10 customers
top_customers = (
    sales_data.groupby("CUSTOMERNAME")["SALES"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

top_customers
# Out:
#                    CUSTOMERNAME      SALES
# 0         Euro Shopping Channel  912294.11
# 1  Mini Gifts Distributors Ltd.  654858.06
# 2    Australian Collectors, Co.  200995.41
# 3            Muscle Machine Inc  197736.94
# 4             La Rochelle Gifts  180124.90
# 5       Dragon Souveniers, Ltd.  172989.68
# 6             Land of Toys Inc.  164069.44
# 7     The Sharp Gifts Warehouse  160010.27
# 8                AV Stores, Co.  157807.81
# 9       Anna's Decorations, Ltd  153996.13

# %%
#Top 10 customers visual
import plotly.express as px

fig = px.bar(
    top_customers,
    x="CUSTOMERNAME",
    y="SALES",
    color="SALES",
    text_auto=".2s",
    title="Top 10 Customers by Sales"
)

fig.update_layout(xaxis_tickangle=-45)

fig.show()

# %%
country_sales = (
    sales_data.groupby("COUNTRY")["SALES"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

country_sales
# Out:
#         COUNTRY       SALES
# 0           USA  3627982.83
# 1         Spain  1215686.92
# 2        France  1110916.52
# 3     Australia   630623.10
# 4            UK   478880.46
# 5         Italy   374674.31
# 6       Finland   329581.91
# 7        Norway   307463.70
# 8     Singapore   288488.41
# 9       Denmark   245637.15
# 10       Canada   224078.56
# 11      Germany   220472.09
# 12       Sweden   210014.21
# 13      Austria   202062.53
# 14        Japan   188167.81
# 15  Switzerland   117713.56
# 16      Belgium   108412.62
# 17  Philippines    94015.73
# 18      Ireland    57756.43

# %%
#country analysis
fig = px.choropleth(
    country_sales,
    locations="COUNTRY",
    locationmode="country names",
    color="SALES",
    hover_name="COUNTRY",
    title="Global Sales Distribution"
)

fig.show()

# %%
#Corelation analysis
import plotly.express as px

correlation = sales_data.select_dtypes(include=["int64","float64"]).corr()

fig = px.imshow(
    correlation,
    text_auto=True,
    aspect="auto",
    title="Correlation Heatmap"
)

fig.show()

# %%
#outlier detection
fig = px.box(
    sales_data,
    y="SALES",
    title="Outlier Detection for Sales"
)

fig.show()

# %%
#Sales Trend by Year and Month
trend = sales_data.groupby(["YEAR_ID","MONTH_NAME"])["SALES"].sum().reset_index()

fig = px.line(
    trend,
    x="MONTH_NAME",
    y="SALES",
    color="YEAR_ID",
    markers=True,
    title="Year-wise Monthly Sales Trend"
)

fig.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("Machine Learning Libraries Imported Successfully!")
# Out:
# Machine Learning Libraries Imported Successfully!

# %%
#Select Features


X = sales_data[["QUANTITYORDERED", "PRICEEACH", "MSRP"]]

X.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  MSRP
# 0               30      95.70    95
# 1               34      81.35    95
# 2               41      94.74    95
# 3               45      83.26    95
# 4               49     100.00    95

# %%
#Select Target Variable


y = sales_data["SALES"]

y.head()
# Out:
# 0    2871.00
# 1    2765.90
# 2    3884.34
# 3    3746.70
# 4    5205.27
# Name: SALES, dtype: float64

# %%
#Split Dataset

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)
print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (2258, 3)
# Testing Features  : (565, 3)
# Training Target   : (2258,)
# Testing Target    : (565,)

# %%
#Create Linear Regression Model


model = LinearRegression()

print("Model Created Successfully!")
# Out:
# Model Created Successfully!

# %%
#Train the Model


model.fit(X_train, y_train)

print("Model Trained Successfully!")
# Out:
# Model Trained Successfully!

# %%
#Predict the sales
y_pred = model.predict(X_test)

print("Prediction Completed!")
# Out:
# Prediction Completed!

# %%
#Compare Actual vs Predicted


comparison = X_test.copy()

comparison["Actual Sales"] = y_test

comparison["Predicted Sales"] = y_pred

comparison.head(10)
# Out:
#       QUANTITYORDERED  PRICEEACH  MSRP  Actual Sales  Predicted Sales
# 1091               21      73.17    80       1536.57      1386.722531
# 2328               25      86.74   102       2168.50      2652.481188
# 1474               39     100.00   112       4351.23      4734.883634
# 1437               60      64.67    73       3880.20      4864.919015
# 1105               43      70.76    80       3042.68      3501.787342
# 239                49     100.00   136       7969.36      6092.067500
# 1366               39     100.00    50       7827.30      3825.236495
# 1407               23      72.70    71       1672.10      1436.953335
# 1858               34      68.49    85       2328.66      2580.098347
# 1061               55     100.00   169       8289.05      7179.271962

# %%
#Model Evaluation


print("Mean Absolute Error :", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error  :", mean_squared_error(y_test, y_pred))
print("R² Score            :", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error : 653.0680867292311
# Mean Squared Error  : 1045246.550427747
# R² Score            : 0.7605331377928034

# %%
#Actual vs Predicted Sales


import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(y_test, y_pred)

plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")

plt.grid(True)

plt.show()

# %%
#Feature Coefficients

coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_
})

coefficients
# Out:
#            Feature  Coefficient
# 0  QUANTITYORDERED   100.506239
# 1        PRICEEACH    39.864089
# 2             MSRP    14.671728

# %%
# Recommendation 1 : Top Selling Product Lines


top_productline = (
    sales_data.groupby("PRODUCTLINE")["SALES"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

print("Top Selling Product Lines")
top_productline
# Out:
# Top Selling Product Lines
#         PRODUCTLINE       SALES
# 0      Classic Cars  3919615.66
# 1      Vintage Cars  1903150.84
# 2       Motorcycles  1166388.34
# 3  Trucks and Buses  1127789.84
# 4            Planes   975003.57
# 5             Ships   714437.13
# 6            Trains   226243.47

# %%
import plotly.express as px

fig = px.bar(
    top_productline,
    x="PRODUCTLINE",
    y="SALES",
    color="SALES",
    text_auto=".2s",
    title="Top Selling Product Lines"
)

fig.update_layout(
    xaxis_title="Product Line",
    yaxis_title="Total Sales"
)

fig.show()

# %%
best_product = top_productline.iloc[0]

print("Highest Selling Product Line :", best_product["PRODUCTLINE"])
print("Total Sales :", best_product["SALES"])
# Out:
# Highest Selling Product Line : Classic Cars
# Total Sales : 3919615.66

# %%
print("-----------------------------------------------------")
print("Recommendation 1 : Inventory Management")
print("-----------------------------------------------------")

print(
    f"""
The product line '{best_product['PRODUCTLINE']}' generated the highest total sales
({best_product['SALES']:.2f}).

Recommendation:
Increase inventory levels for this product line, especially before peak sales periods.
The Machine Learning model identified that variables such as Quantity Ordered and Price
have a strong influence on Sales, indicating that maintaining sufficient inventory
for high-demand products can help reduce stock shortages and improve revenue.
"""
)
# Out:
# -----------------------------------------------------
# Recommendation 1 : Inventory Management
# -----------------------------------------------------
#
# The product line 'Classic Cars' generated the highest total sales
# (3919615.66).
#
# Recommendation:
# Increase inventory levels for this product line, especially before peak sales periods.
# The Machine Learning model identified that variables such as Quantity Ordered and Price
# have a strong influence on Sales, indicating that maintaining sufficient inventory
# for high-demand products can help reduce stock shortages and improve revenue.

# %%
# Recommendation 2 : Pricing Strategy


price_analysis = (
    sales_data.groupby("PRODUCTLINE")
    .agg({
        "PRICEEACH": "mean",
        "SALES": "sum"
    })
    .reset_index()
)

price_analysis
# Out:
#         PRODUCTLINE  PRICEEACH       SALES
# 0      Classic Cars  87.335781  3919615.66
# 1       Motorcycles  82.997553  1166388.34
# 2            Planes  81.740915   975003.57
# 3             Ships  83.855470   714437.13
# 4            Trains  75.654675   226243.47
# 5  Trucks and Buses  87.527940  1127789.84
# 6      Vintage Cars  78.148204  1903150.84

# %%
The company should implement a data-driven pricing strategy by maintaining premium pricing
for high-demand product lines while introducing targeted discounts or promotional offers for 
lower-performing products. This approach can maximize revenue, improve competitiveness, and 
increase sales without reducing profitability across all product categories.

# %%
import plotly.express as px

fig = px.scatter(
    price_analysis,
    x="PRICEEACH",
    y="SALES",
    color="PRODUCTLINE",
    size="SALES",
    hover_name="PRODUCTLINE",
    title="Average Price vs Total Sales by Product Line"
)

fig.update_layout(
    xaxis_title="Average Price",
    yaxis_title="Total Sales"
)

fig.show()

# %%
#recommondation 3
top_customers = (
    sales_data.groupby("CUSTOMERNAME")["SALES"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

top_customers
# Out:
#                    CUSTOMERNAME      SALES
# 0         Euro Shopping Channel  912294.11
# 1  Mini Gifts Distributors Ltd.  654858.06
# 2    Australian Collectors, Co.  200995.41
# 3            Muscle Machine Inc  197736.94
# 4             La Rochelle Gifts  180124.90
# 5       Dragon Souveniers, Ltd.  172989.68
# 6             Land of Toys Inc.  164069.44
# 7     The Sharp Gifts Warehouse  160010.27
# 8                AV Stores, Co.  157807.81
# 9       Anna's Decorations, Ltd  153996.13

# %%
Recommendation

The company should focus on customer retention by introducing loyalty programs, 
personalized discounts, exclusive offers, and dedicated customer support for its 
top customers. Retaining high-value customers can lead to increased repeat purchases,
stronger customer relationships, and sustainable long-term business growth.

# %%
fig = px.bar(
    top_customers,
    x="SALES",
    y="CUSTOMERNAME",
    orientation="h",
    color="SALES",
    text_auto=".2s",
    title="Top 10 Customers by Sales"
)

fig.update_layout(
    yaxis_title="Customer",
    xaxis_title="Total Sales"
)

fig.show()

# %%
# Recommendation 4 : Monthly Sales Trend


monthly_sales = (
    sales_data.groupby("MONTH_ID")["SALES"]
    .sum()
    .reset_index()
)

monthly_sales
# Out:
#     MONTH_ID       SALES
# 0          1   785874.44
# 1          2   810441.90
# 2          3   754501.39
# 3          4   669390.96
# 4          5   923972.56
# 5          6   454756.78
# 6          7   514875.97
# 7          8   659310.57
# 8          9   584724.27
# 9         10  1121215.22
# 10        11  2118885.67
# 11        12   634679.12

# %%
Recommendation

The company should leverage historical sales trends and machine learning predictions
to forecast future demand. By increasing inventory, staffing, and marketing activities 
before peak sales periods and implementing promotional campaigns during low-demand months, 
the company can improve inventory management, reduce stock shortages, optimize operational planning, and maximize overall revenue.

# %%
import plotly.express as px

fig = px.line(
    monthly_sales,
    x="MONTH_ID",
    y="SALES",
    markers=True,
    title="Monthly Sales Trend for Demand Forecasting"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Total Sales"
)

fig.show()

# %%
month_order = [
    "January", "February", "March", "April",
    "May", "June", "July", "August",
    "September", "October", "November", "December"
]

sales_data["MONTH_NAME"] = pd.Categorical(
    sales_data["MONTH_NAME"],
    categories=month_order,
    ordered=True
)

monthly_sales = (
    sales_data.groupby("MONTH_NAME")["SALES"]
    .sum()
    .reset_index()
)

import plotly.express as px

fig = px.line(
    monthly_sales,
    x="MONTH_NAME",
    y="SALES",
    markers=True,
    title="Monthly Sales Trend for Demand Forecasting"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Total Sales"
)

fig.show()
